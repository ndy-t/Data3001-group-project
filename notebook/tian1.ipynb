# %%
from clouddrift.datasets import gdp1h
from pathlib import Path
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

ds = gdp1h()
ds.isel(traj=slice(0, 10))
# Out:
# <xarray.Dataset> Size: 16GB
# Dimensions:                (traj: 10, obs: 197214787)
# Coordinates:
#     id                     (traj) int64 80B ...
#     time                   (obs) datetime64[ns] 2GB ...
# Dimensions without coordinates: traj, obs
# Data variables: (12/58)
#     BuoyTypeManufacturer   (traj) |S20 200B ...
#     BuoyTypeSensorArray    (traj) |S20 200B ...
#     CurrentProgram         (traj) float64 80B ...
#     DeployingCountry       (traj) |S20 200B ...
#     DeployingShip          (traj) |S20 200B ...
#     DeploymentComments     (traj) int16 20B ...
#     ...                     ...
#     start_lat              (traj) float32 40B ...
#     start_lon              (traj) float32 40B ...
#     typebuoy               (traj) |S10 100B ...
#     typedeath              (traj) int8 10B ...
#     ve                     (obs) float32 789MB ...
#     vn                     (obs) float32 789MB ...
# Attributes: (12/18)
#     Conventions:          CF-1.6
#     acknowledgement:      Elipot, Shane; Sykulski, Adam; Lumpkin, Rick; Centu...
#     contributor_name:     NOAA Global Drifter Program
#     contributor_role:     Data Acquisition Center
#     date_created:         2024-07-30T19:02:16.200531
#     doi:                  10.25921/x46c-3620
#     ...                   ...
#     publisher_name:       GDP Drifter DAC
#     publisher_url:        https://www.aoml.noaa.gov/phod/gdp
#     summary:              Global Drifter Program hourly data
#     time_coverage_end:    2022-10-31:00:00:00Z
#     time_coverage_start:  1987-10-02:13:00:00Z
#     title:                Global Drifter Program hourly drifting buoy collection

# %%
df = pd.read_parquet("../data/processed/gulf_stream_q3_2007_2010.parquet")
print(df.shape)
print(df.columns.tolist())
print(df.head())
# Out:
# (616023, 8)
# ['trajectory_id', 'time', 'lon', 'lat', 've', 'vn', 'drogue_status', 'in_region']
#    trajectory_id                time        lon       lat      ve      vn  \
# 0          42790 2007-07-01 00:00:00 -60.377071  31.36121  0.1257  0.3294
# 1          42790 2007-07-01 01:00:00 -60.372761  31.37212  0.1250  0.3301
# 2          42790 2007-07-01 02:00:00 -60.368851  31.38327  0.1241  0.3313
# 3          42790 2007-07-01 03:00:00 -60.361992  31.38662  0.1420  0.1002
# 4          42790 2007-07-01 04:00:00 -60.353020  31.38908  0.1502  0.1056
#
#    drogue_status  in_region
# 0          False       True
# 1          False       True
# 2          False       True
# 3          False       True
# 4          False       True

# %%
null_summary = pd.DataFrame({
    "null_count": df.isna().sum(),
    "null_percent": df.isna().mean() * 100,
})

null_summary = null_summary.sort_values(
    "null_count",
    ascending=False,
)

display(null_summary)
